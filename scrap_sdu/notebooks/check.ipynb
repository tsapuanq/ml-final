# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/sapuantalaspay/vs_projects/introML/final_ML/scrap_sdu/data/bachelor_ru/parsed/canonical.csv')
df.head()
# Out:
#   lang faculty                                         source_url  \
# 0   ru    ssbl  https://sdu.edu.kz/ru/%D0%B8%D0%BD%D0%B6%D0%B5...
# 1   ru    ssbl  https://sdu.edu.kz/ru/%D0%B8%D0%BD%D0%B6%D0%B5...
# 2   ru    ssbl  https://sdu.edu.kz/ru/%D0%B8%D0%BD%D0%B6%D0%B5...
# 3   ru    ssbl  https://sdu.edu.kz/ru/%D1%84%D0%B0%D0%BA%D1%83...
# 4   ru    ssbl  https://sdu.edu.kz/ru/%D1%84%D0%B0%D0%BA%D1%83...
#
#                                                 slug  \
# 0  ssbl__D0-B1-D0-B0-D0-BA-D0-B0-D0-BB-D0-B0-D0-B...
# 1  ssbl__D0-B4-D0-BE-D0-BA-D1-82-D0-BE-D1-80-D0-B...
# 2  ssbl__D0-BC-D0-B0-D0-B3-D0-B8-D1-81-D1-82-D1-8...
# 3  ssbl__D0-B1-D0-B0-D0-BA-D0-B0-D0-BB-D0-B0-D0-B...
# 4  ssbl__D0-BC-D0-B0-D0-B3-D0-B8-D1-81-D1-82-D1-8...
#
#                           program_name degree program_length  threshold_grant  \
# 0  Похоже, эта страница не существует.    NaN            NaN              NaN
# 1  Похоже, эта страница не существует.    NaN            NaN              NaN
# ...

# %%
df.isna().sum()
# Out:
# lang                    0
# faculty                 0
# source_url              0
# slug                    0
# program_name            0
# degree                 36
# program_length         36
# threshold_grant        36
# threshold_paid         36
# ects                   36
# english_level           0
# program_description    36
# creative_exam           0
# creative_exam_text     46
# http_status             0
# ok                      0
# fetched_at              0
# dtype: int64

# %%
df[df['program_description'].isna()].to_csv('s.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   lang                 47 non-null     object
#  1   faculty              47 non-null     object
#  2   source_url           47 non-null     object
#  3   slug                 47 non-null     object
#  4   program_name         47 non-null     object
#  5   degree               11 non-null     object
#  6   program_length       11 non-null     object
#  7   threshold_grant      11 non-null     float64
#  8   threshold_paid       11 non-null     float64
#  9   ects                 11 non-null     float64
#  10  english_level        47 non-null     object
#  11  program_description  11 non-null     object
#  12  creative_exam        47 non-null     int64
#  13  creative_exam_text   1 non-null      object
#  14  http_status          47 non-null     int64
# ...
